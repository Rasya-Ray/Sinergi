# %%
!pip install torch transformers pandas scikit-learn rapidfuzz idna httpx beautifulsoup4
# Out:
# Error in parse(text = input): <text>:1:6: unexpected symbol
# 1: !pip install
#          ^
# Traceback:
